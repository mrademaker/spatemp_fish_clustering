# %%
import geopandas as gpd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import seaborn as sns
import pandas as pd
from shapely.geometry import Point


# %load_ext autoreload
# %autoreload 2
sns.set()
# %matplotlib inline

# %% [markdown]
# ##  1. Using original normalized distance measure for biomass

# %%
from scipy import spatial

params = {"distance":{"fieldnames":{"x":"ShootLong","y":"ShootLat"},"function": lambda x,y: spatial.distance.cdist([x],y), 
                      "normalize_n": None, "normalize_k":12,"normalize_mean": False, "weights":1.0}, #Euclidean distance between two points, normalized by the maximum distance of the 6 nearest neighbors
          
          "timedistance":{"fieldnames":{"datetime":"YearQuarter"},"function": lambda x,y: np.abs(x-y),
                                        "normalize_n": None, "normalize_k":12,"normalize_mean": False, "weights":1.0}, #Euclidean distance between two points, normalized by the maximum distance of the 6 nearest neighbors
          
          "attributes":{"fieldnames":["Gadus_morhua_juvenile","Gadus_morhua_adult","Quarter"],
                        "function": [lambda x,y: np.abs(x-y)/max(max(np.max(x),np.max(y)),1),lambda x,y: np.abs(x-y)/max(max(np.max(x),np.max(y)),1),lambda x,y: np.abs(x-y)],
                        "normalize_n":[1,1,1], "normalize_k": [None,None,None], "normalize_mean": [False,False,False], "weights":[1.0,1.0,1.0]}} #Absolute difference between two values, normalized by the average of that field

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('/Users/markrademaker/Projects/Spatio_temporal_clustering/Script/sthc_mark.py'))
if module_path not in sys.path:
    sys.path.append(module_path)
from sthc_mark import STHC

file_dir ='/Users/markrademaker/Projects/Spatio_temporal_clustering/'

st = STHC()

st.load_dataset_csv('/Users/markrademaker/Projects/Spatio_temporal_clustering/Data/Gadus_morhua_1991_2019_juv_adult_biomass.csv',
                    params,toepsg=4326) #st.df.head()
# Out:
# Reading the file...
# ShootLong
# ShootLat
# Processing table for datetime and coordinates...
# Preparing attribute normalization....

# %%
from scipy import spatial
from scipy.cluster.hierarchy import cophenet
from scipy.spatial.distance import pdist

linkage_methods=['single','complete','average','weighted','centroid','median','ward']
for method in linkage_methods:
    st.calculate_distance_matrix()
    st.calculate_clusters(method=method)
# Out:
# Using single method
# Mean cophenetic correlation coefficient = 0.16142645762207442
#
# Using complete method
# Mean cophenetic correlation coefficient = 0.6245595040845626
#
# Using average method
# Mean cophenetic correlation coefficient = 0.6610717088389783
#
# Using weighted method
# Mean cophenetic correlation coefficient = 0.6360020431651704
#
# Using centroid method
# Mean cophenetic correlation coefficient = 0.6590341385558671
#
# Using median method
# Mean cophenetic correlation coefficient = 0.6020060501464326
#
# Using ward method
# Mean cophenetic correlation coefficient = 0.6407855163260908

# %%
#recalculate distance with best performing method and plot results
st.calculate_clusters(method='average')
# Out:
# Using average method
# Mean cophenetic correlation coefficient = 0.6610717088389783

# %%
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import fcluster

fig = plt.figure(figsize=(10,10),dpi=300)
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Index')
plt.ylabel('Distance')
row_dendr = dendrogram(st.row_clusters)
frame1 = plt.gca()
frame1.axes.xaxis.set_ticklabels([])
plt.show()

# %%
gdf = gpd.GeoDataFrame(st.df,geometry=st.df[['ShootLong','ShootLat']].apply(lambda x: Point(x),axis=1),crs={'init': 'epsg:4326'})
cluster_labels = fcluster(st.row_clusters, 4, criterion='maxclust')
gdf['clusters'] = cluster_labels
gdf.plot(column='clusters');
# Out:
# /Users/markrademaker/opt/anaconda3/envs/my_env/lib/python3.7/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
import contextily as ctx
#If using contextily, the projection needs to be web mercator.

gdf = gdf.to_crs(epsg=4326)
#export gdf to plot in QGIS
gdf1 = pd.DataFrame(gdf)
gdf1.head()
gdf1.to_csv('/Users/markrademaker/Projects/Spatio_temporal_clustering/Data/cod_cluster_gdf.csv')

# %%
for c in gdf['clusters'].unique():
    fig = plt.figure(figsize=(8,8),constrained_layout=True)
    gs = fig.add_gridspec(3, 3)
    ax_map = fig.add_subplot(gs[0:2, 0:])
    ax_map.set_aspect('equal')
    ax_map.set_title("Cluster {0} Coordinates".format(c))
    ax_timerange = fig.add_subplot(gs[2, 0])
    ax_variables = fig.add_subplot(gs[2, 1:])
    gdf[gdf['clusters']==c].plot(ax=ax_map)
    ax_map.set_xticks([])
    ax_map.set_yticks([])
    ax_map.set_xlim([gdf['geometry'].total_bounds[0],gdf['geometry'].total_bounds[2]])
    ax_map.set_ylim([gdf['geometry'].total_bounds[1],gdf['geometry'].total_bounds[3]])
    ctx.add_basemap(ax_map)
    ax_timerange.scatter(gdf[gdf['clusters']==c].index,gdf[gdf['clusters']==c][params['timedistance']['fieldnames']['datetime']])
    gdf[gdf['clusters']==c][params['attributes']['fieldnames']].boxplot(ax=ax_variables)
    plt.savefig("cluster_{0}.png".format(c),dpi=300)
    plt.close()
# Out:
# /Users/markrademaker/opt/anaconda3/envs/my_env/lib/python3.7/site-packages/contextily/tile.py:629: UserWarning: The inferred zoom level of 23 is not valid for the current tile provider (valid zooms: 0 - 18).
#   warnings.warn(msg)
# /Users/markrademaker/opt/anaconda3/envs/my_env/lib/python3.7/site-packages/contextily/tile.py:629: UserWarning: The inferred zoom level of 23 is not valid for the current tile provider (valid zooms: 0 - 18).
#   warnings.warn(msg)
# /Users/markrademaker/opt/anaconda3/envs/my_env/lib/python3.7/site-packages/contextily/tile.py:629: UserWarning: The inferred zoom level of 23 is not valid for the current tile provider (valid zooms: 0 - 18).
#   warnings.warn(msg)
# /Users/markrademaker/opt/anaconda3/envs/my_env/lib/python3.7/site-packages/contextily/tile.py:629: UserWarning: The inferred zoom level of 23 is not valid for the current tile provider (valid zooms: 0 - 18).
#   warnings.warn(msg)

# %% [markdown]
# ##  2. Using (non-normalized) absolute distance for biomass

# %%
from scipy import spatial

params = {"distance":{"fieldnames":{"x":"ShootLong","y":"ShootLat"},"function": lambda x,y: spatial.distance.cdist([x],y), 
                      "normalize_n": None, "normalize_k":12,"normalize_mean": False, "weights":1.0}, #Euclidean distance between two points, normalized by the maximum distance of the 6 nearest neighbors
          
          "timedistance":{"fieldnames":{"datetime":"YearQuarter"},"function": lambda x,y: np.abs(x-y),
                                        "normalize_n": None, "normalize_k":12,"normalize_mean": False, "weights":1.0}, #Euclidean distance between two points, normalized by the maximum distance of the 6 nearest neighbors
          
          "attributes":{"fieldnames":["Gadus_morhua_juvenile","Gadus_morhua_adult","Quarter"],
                        "function": [lambda x,y: np.abs(x-y),lambda x,y: np.abs(x-y),lambda x,y: np.abs(x-y)],
                        "normalize_n":[1,1,1], "normalize_k": [None,None,None], "normalize_mean": [False,False,False], "weights":[1.0,1.0,1.0]}} #Absolute difference between two values, normalized by the average of that field

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('/Users/markrademaker/Projects/Spatio_temporal_clustering/Script/sthc_mark.py'))
if module_path not in sys.path:
    sys.path.append(module_path)
from sthc_mark import STHC

file_dir ='/Users/markrademaker/Projects/Spatio_temporal_clustering/'

st = STHC()

st.load_dataset_csv('/Users/markrademaker/Projects/Spatio_temporal_clustering/Data/Gadus_morhua_1991_2019_juv_adult_biomass.csv',
                    params,toepsg=4326) #st.df.head()
# Out:
# Reading the file...
# ShootLong
# ShootLat
# Processing table for datetime and coordinates...
# Preparing attribute normalization....

# %%
from scipy import spatial
from scipy.cluster.hierarchy import cophenet
from scipy.spatial.distance import pdist

linkage_methods=['single','complete','average','weighted','centroid','median','ward']
for method in linkage_methods:
    st.calculate_distance_matrix()
    st.calculate_clusters(method=method)
# Out:
# Using single method
# Mean cophenetic correlation coefficient = 0.7863073514536657
#
# Using complete method
# Mean cophenetic correlation coefficient = 0.8363524273435613
#
# Using average method
# Mean cophenetic correlation coefficient = 0.9705158555883353
#
# Using weighted method
# Mean cophenetic correlation coefficient = 0.9520315556645859
#
# Using centroid method
# Mean cophenetic correlation coefficient = 0.9549357430737341
#
# Using median method
# Mean cophenetic correlation coefficient = 0.924465094784696
#
# Using ward method
# Mean cophenetic correlation coefficient = 0.5361614709035509

# %%
#recalculate distance with best performing method and plot results
st.calculate_clusters(method='average')
# Out:
# Using average method
# Mean cophenetic correlation coefficient = 0.9705158555883353

# %%
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import fcluster

fig = plt.figure(figsize=(10,10),dpi=300)
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Index')
plt.ylabel('Distance')
row_dendr = dendrogram(st.row_clusters)
frame1 = plt.gca()
frame1.axes.xaxis.set_ticklabels([])
plt.show()

# %% [markdown]
# ##  3. Using z-score normalized  biomass and absolute distance

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('/Users/markrademaker/Projects/Spatio_temporal_clustering/Script/sthc_mark.py'))
if module_path not in sys.path:
    sys.path.append(module_path)
from sthc_mark import STHC

file_dir ='/Users/markrademaker/Projects/Spatio_temporal_clustering/'

st = STHC()

st.load_dataset_csv('/Users/markrademaker/Projects/Spatio_temporal_clustering/Data/Gadus_morhua_1991_2019_juv_adult_biomass.csv',
                    params,toepsg=4326)

st.df['Gadus_morhua_adult']= (st.df['Gadus_morhua_adult'] - st.df['Gadus_morhua_adult'].mean())/st.df['Gadus_morhua_adult'].std(ddof=0)
st.df['Gadus_morhua_juvenile']= (st.df['Gadus_morhua_juvenile'] - st.df['Gadus_morhua_juvenile'].mean())/st.df['Gadus_morhua_juvenile'].std(ddof=0)
# Out:
# Reading the file...
# ShootLong
# ShootLat
# Processing table for datetime and coordinates...
# Preparing attribute normalization....

# %%
from scipy import spatial
from scipy.cluster.hierarchy import cophenet
from scipy.spatial.distance import pdist

linkage_methods=['single','complete','average','weighted','centroid','median','ward']
for method in linkage_methods:
    st.calculate_distance_matrix()
    st.calculate_clusters(method=method)
# Out:
# Using single method
# Mean cophenetic correlation coefficient = 0.7863073514536657
#
# Using complete method
# Mean cophenetic correlation coefficient = 0.8363524273435613
#
# Using average method
# Mean cophenetic correlation coefficient = 0.9705158555883353
#
# Using weighted method
# Mean cophenetic correlation coefficient = 0.9520315556645859
#
# Using centroid method
# Mean cophenetic correlation coefficient = 0.9549357430737341
#
# Using median method
# Mean cophenetic correlation coefficient = 0.924465094784696
#
# Using ward method
# Mean cophenetic correlation coefficient = 0.5361614709035509

# %%
#recalculate distance with best performing method and plot results
st.calculate_clusters(method='average')
# Out:
# Using average method
# Mean cophenetic correlation coefficient = 0.9705158555883353

# %%
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import fcluster

fig = plt.figure(figsize=(10,10),dpi=300)
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Index')
plt.ylabel('Distance')
row_dendr = dendrogram(st.row_clusters)
frame1 = plt.gca()
frame1.axes.xaxis.set_ticklabels([])
plt.show()

# %% [markdown]
# ## 4. Using log10 transformed (x,y) * max(log10(x),log10(y)) distance function for biomass

# %%
params = {"distance":{"fieldnames":{"x":"ShootLong","y":"ShootLat"},"function": lambda x,y: spatial.distance.cdist([x],y), 
                      "normalize_n": None, "normalize_k":12,"normalize_mean": False, "weights":1.0}, #Euclidean distance between two points, normalized by the maximum distance of the 6 nearest neighbors

          "timedistance":{"fieldnames":{"datetime":"YearQuarter"},"function": lambda x,y: np.abs(x-y),
                                        "normalize_n": None, "normalize_k":12,"normalize_mean": False, "weights":1.0}, #Euclidean distance between two points, normalized by the maximum distance of the 6 nearest neighbors

          "attributes":{"fieldnames":["Gadus_morhua_juvenile","Gadus_morhua_adult","Quarter"],
                        "function": [lambda x,y: np.abs(x-y)*max(np.max(x),np.max(y)),lambda x,y: np.abs(x-y)*max(np.max(x),np.max(y)),lambda x,y: np.abs(x-y)],
                        "normalize_n":[1,1,1], "normalize_k": [None,None,None], "normalize_mean": [False,False,False], "weights":[1.0,1.0,1.0]}} #Absolute difference between two values, normalized by the average of that field

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('/Users/markrademaker/Projects/Spatio_temporal_clustering/Script/sthc_mark.py'))
if module_path not in sys.path:
    sys.path.append(module_path)
from sthc_mark import STHC

file_dir ='/Users/markrademaker/Projects/Spatio_temporal_clustering/'

st = STHC()

st.load_dataset_csv('/Users/markrademaker/Projects/Spatio_temporal_clustering/Data/Gadus_morhua_1991_2019_juv_adult_biomass.csv',
                    params,toepsg=4326)#st.df.head()

st.df['Gadus_morhua_adult']= np.log10(st.df['Gadus_morhua_adult']+1)
st.df['Gadus_morhua_juvenile']= np.log10(st.df['Gadus_morhua_juvenile']+1)
# Out:
# Reading the file...
# ShootLong
# ShootLat
# Processing table for datetime and coordinates...
# Preparing attribute normalization....

# %%
from scipy import spatial
from scipy.cluster.hierarchy import cophenet
from scipy.spatial.distance import pdist

linkage_methods=['single','complete','average','weighted','centroid','median','ward']
for method in linkage_methods:
    st.calculate_distance_matrix()
    st.calculate_clusters(method=method)
# Out:
# Using single method
# Mean cophenetic correlation coefficient = 0.7075695637807827
#
# Using complete method
# Mean cophenetic correlation coefficient = 0.8944601619676689
#
# Using average method
# Mean cophenetic correlation coefficient = 0.938191718522037
#
# Using weighted method
# Mean cophenetic correlation coefficient = 0.9143257873037061
#
# Using centroid method
# Mean cophenetic correlation coefficient = 0.9383956916522582
#
# Using median method
# Mean cophenetic correlation coefficient = 0.9234778303803647
#
# Using ward method
# Mean cophenetic correlation coefficient = 0.5071124681292299

# %%
#recalculate distance with best performing method and plot results
st.calculate_clusters(method='average')
# Out:
# Using average method
# Mean cophenetic correlation coefficient = 0.938191718522037

# %%
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import fcluster

fig = plt.figure(figsize=(10,10),dpi=300)
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Index')
plt.ylabel('Distance')
row_dendr = dendrogram(st.row_clusters)
frame1 = plt.gca()
frame1.axes.xaxis.set_ticklabels([])
plt.show()

# %% [markdown]
# ## 5. Using Length, Weigth, Abundance

# %%
from sthc import STHC
params = {"distance":{"fieldnames":{"x":"ShootLong","y":"ShootLat"},"function": lambda x,y: spatial.distance.cdist([x],y), 
                      "normalize_n": None, "normalize_k":12,"normalize_mean": False, "weights":1.0}, #Euclidean distance between two points, normalized by the maximum distance of the 6 nearest neighbors
          
           # Try YearQuarter time distance -> still absolute measure
          "timedistance":{"fieldnames":{"datetime":"YearQuarter"},"function": lambda x,y: np.abs(x-y),
                                        "normalize_n": None, "normalize_k":12,"normalize_mean": False, "weights":1.0}, #Euclidean distance between two points, normalized by the maximum distance of the 6 nearest neighbors
          
          "attributes":{"fieldnames":["LngtClass_cm","CPUE_number_per_hour","Biomass_kg","Quarter"],#"Maturity",
                        "function": [lambda x,y: np.abs(x-y),#/max(max(np.max(x),np.max(y)),1),#LngtClass
                                     lambda x,y: np.abs(x-y),#/max(max(np.max(x),np.max(y)),1),#Catch per unit effort
                                     lambda x,y: np.abs(x-y),#/max(max(np.max(x),np.max(y)),1),#Biomass
                                     lambda x,y: np.abs(x-y),#Maturity
                                     lambda x,y: np.abs(x-y),#Quarter
                                    ],
                        "normalize_n":[1,1,1,1], "normalize_k": [None,None,None,None], "normalize_mean": [False,False,False,False], "weights":[1.0,1.0,1.0,1.0]}} #Absolute difference between two values, normalized by the average of that field

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('/Users/markrademaker/Projects/Spatio_temporal_clustering/Script/sthc_mark.py'))
if module_path not in sys.path:
    sys.path.append(module_path)
from sthc_mark import STHC

file_dir ='/Users/markrademaker/Projects/Spatio_temporal_clustering/'

st = STHC()

st.load_dataset_csv('/Users/markrademaker/Projects/Spatio_temporal_clustering/Data/Gadus_morhua_1991_2019_length_weight_cpue.csv',
                    params,toepsg=4326)#,sample=10000) #st.df.head()
#normalize all features
cols=['ShootLong','ShootLat','YearQuarter','LngtClass_cm','CPUE_number_per_hour','Biomass_kg','Quarter']
for col in cols:
    st.df[col] = (st.df[col] - st.df[col].mean())/st.df[col].std(ddof=0)
# Out:
# Reading the file...
# ShootLong
# ShootLat
# Processing table for datetime and coordinates...

# %%
from scipy import spatial
from scipy.cluster.hierarchy import cophenet
from scipy.spatial.distance import pdist

linkage_methods=['single','complete','average','weighted','centroid','median','ward']
for method in linkage_methods:
    st.calculate_distance_matrix()
    st.calculate_clusters(method=method)
# Out:
# Using single method
# Mean cophenetic correlation coefficient = 0.15281775710417167
#
# Using complete method
# Mean cophenetic correlation coefficient = 0.6902498978680154
#
# Using average method
# Mean cophenetic correlation coefficient = 0.6994046814026481
#
# Using weighted method
# Mean cophenetic correlation coefficient = 0.6739732044563786
#
# Using centroid method
# Mean cophenetic correlation coefficient = 0.7118241222508924
#
# Using median method
# Mean cophenetic correlation coefficient = 0.6481134338740303
#
# Using ward method
# Mean cophenetic correlation coefficient = 0.6972466676364147

# %%
#recalculate distance with best performing method and plot results
st.calculate_clusters(method='centroid')
# Out:
# Using centroid method
# Mean cophenetic correlation coefficient = 0.7118241222508924

# %%
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import fcluster

fig = plt.figure(figsize=(10,10),dpi=300)
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Index')
plt.ylabel('Distance')
row_dendr = dendrogram(st.row_clusters)
frame1 = plt.gca()
frame1.axes.xaxis.set_ticklabels([])
plt.show()

# %%
a = st.elbow_plot()

# %%
a = st.elbow_alt()

# %%
a = st.silhoutte_scores_n_clusters()

# %%
cluster_labels = fcluster(st.row_clusters, 32, criterion='maxclust')

# %%
gdf = gpd.GeoDataFrame(st.df,geometry=st.df[['ShootLong','ShootLat']].apply(lambda x: Point(x),axis=1),crs={'init': 'epsg:32631'})
gdf['clusters'] = cluster_labels
gdf.plot(column='clusters');

# %% [markdown]
# ## create custom dendrogam

# %%
def fancy_dendrogram(*args, **kwargs):
    max_d = kwargs.pop('max_d', None)
    if max_d and 'color_threshold' not in kwargs:
        kwargs['color_threshold'] = max_d
    annotate_above = kwargs.pop('annotate_above', 0)

    ddata = dendrogram(*args, **kwargs)

    if not kwargs.get('no_plot', False):
        plt.title('Hierarchical Clustering Dendrogram (truncated)')
        plt.xlabel('sample index or (cluster size)')
        plt.ylabel('distance')
        for i, d, c in zip(ddata['icoord'], ddata['dcoord'], ddata['color_list']):
            x = 0.5 * sum(i[1:3])
            y = d[1]
            if y > annotate_above:
                plt.plot(x, y, 'o', c=c)
                plt.annotate("%.3g" % y, (x, y), xytext=(0, -5),
                             textcoords='offset points',
                             va='top', ha='center')
        if max_d:
            plt.axhline(y=max_d, c='k')
    return ddata

# %%
fancy_dendrogram(
    st.row_clusters,
    truncate_mode='lastp',
    p=12,
    leaf_rotation=90.,
    leaf_font_size=12.,
    show_contracted=True,
    annotate_above=10,  # useful in small plots so annotations don't overlap
)
plt.show()

# %%
# set cut-off to 50
max_d = 0.75  # max_d as in max_distance
